# %% [markdown]
# <a href="https://colab.research.google.com/github/iamZaid-Alam/Maths-for-ML/blob/main/linear_algebra_1/linear_algebra_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We know that, y = mx + c
# m is slope, here m = 1/(3)**(1/2)
# so 1/(3)**(1/2) = tan(30)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
